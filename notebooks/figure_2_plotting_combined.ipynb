# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pickle as pkl
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
species = {'alpha1': [32, 42],
           'alpha2': [3, 10, 28, 29],
           'alpha3': [61],
           'alpha4': [2, 27, 57],
           'alpha5': [51, 69],
           'alpha6': [56],
           'alpha7': [18, 39, 45, 59, 68, 70],
           'alpha8': [7],
           'alpha9': [16, 31, 33, 35, 52, 58, 67],
           'alpha11': [34],
           'alpha13': [54],
           'beta1': [5, 8, 12, 14, 19, 20, 21, 24, 25, 36, 47, 93], 
           'beta2': [9, 15, 17, 22, 23, 37, 38, 80, 100, 151],
           'beta3': [49, 75, 76], 
           'beta4': [92],
           'beta5': [96],
           'gamma1': [4, 65, 95], 
           'gamma2': [48],
           'gamma3': [50],
           'gamma4': [60],
           'gamma5': [88],
           'gamma12': [132],
           'gamma24': [197],
           'mu': [1],
           'nu': [41],
}

inverted_dict = {}
for specy, types in species.items():
    for typ in types:
        inverted_dict[typ] = specy
        
inverted_dict = {'HPV' + str(i): inverted_dict[i] for i in sorted(inverted_dict.keys())}

types_interested = [i for i in inverted_dict.keys()]

# %%
import matplotlib.path as mpath
import matplotlib.patches as mpatches


def add_label_band(ax, top, bottom, label, *,
                   spine_pos=-0.05, tip_pos=-0.02,
                   rotation=0):
    """
    Helper function to add bracket around y-tick labels.

    Parameters
    ----------
    ax : matplotlib.Axes
        The axes to add the bracket to

    top, bottom : floats
        The positions in *data* space to bracket on the y-axis

    label : str
        The label to add to the bracket

    spine_pos, tip_pos : float, optional
        The position in *axes fraction* of the spine and tips of the bracket.
        These will typically be negative

    Returns
    -------
    bracket : matplotlib.patches.PathPatch
        The "bracket" Aritst.  Modify this Artist to change the color etc of
        the bracket from the defaults.

    txt : matplotlib.text.Text
        The label Artist.  Modify this to change the color etc of the label
        from the defaults.

    """
    # grab the yaxis blended transform
    transform = ax.get_yaxis_transform()

    # add the bracket
    bracket = mpatches.PathPatch(
        mpath.Path(
            [
                [tip_pos, top],
                [spine_pos, top],
                [spine_pos, bottom],
                [tip_pos, bottom],
            ]
        ),
        transform=transform,
        clip_on=False,
        facecolor="none",
        edgecolor="k",
        linewidth=1,
    )
    ax.add_artist(bracket)

    # add the label
    txt = ax.text(
        spine_pos,
        (top + bottom) / 2,
        label,
        ha="right",
        va="center",
        rotation=rotation,
        clip_on=False,
        transform=transform,
    )

    return bracket, txt

# %%
def split_string(s):
    return (''.join(c for c in s if c.isdigit()) or None, 
        ''.join(c for c in s if c.isalpha()) or None)

# %%
threshold = 0.8
proteins = ['E1', 'E2', 'E6', 'E7']
lognorm = True
colormap = 'Blues'

# %%
viruses = pd.read_csv('../results/figure_2_all_alleles_viruses.csv')['0'].values
with open('../results/figure_2_all_allele_threshold_' +  str(threshold) + '.pkl', 'rb') as file:
    results = pkl.load(file)
np.fill_diagonal(results[0], 0)
np.fill_diagonal(results[1], 0)
np.fill_diagonal(results[2], 0)
np.fill_diagonal(results[3], 0)

# %%
from matplotlib.colors import SymLogNorm

i = 0
fig, axes = plt.subplots(2, 2, figsize=(30, 26), facecolor='white')
for axis in axes:
    for ax in axis:
        temp_results = pd.DataFrame(results[i], columns=viruses).set_index(viruses)
        temp_results = temp_results[types_interested][temp_results.index.isin(types_interested)]
        temp_results['species'] = temp_results.index.map(inverted_dict)
        #  = temp_results.species.apply(split_string)
        temp_results[['num_species', 'let_species']] = np.concatenate(
        [[i[0], i[1]] for i in temp_results.species.apply(split_string)]).reshape(-1, 2)
        temp_results['num_species'] = temp_results['num_species'].fillna(0)
        temp_results['num_species'] = temp_results['num_species'].astype(int)
        temp_results['num_type'] = temp_results.index.to_series().apply(lambda x: int(x[3:]))
        temp_results = temp_results.sort_values(['let_species', 'num_species', 'num_type'])
        temp_results = temp_results[list(temp_results.index)]
        im = ax.imshow(temp_results.values,
                       cmap=colormap,
                       norm=SymLogNorm(0.75, vmax=results.max()) if lognorm else None,
#                        vmax= (results.max() if shared_axis else None),
                       )
        cbar = fig.colorbar(im, ax=ax, shrink=0.90, ticks=[0, 1, 10]) # asdfasdf
        ax.set_xticks(np.arange(len(temp_results)))
        ax.set_xticklabels(list(temp_results.index))
        ax.set_yticks(np.arange(len(temp_results)))
        ax.set_yticklabels(list(temp_results.index))
        ax.tick_params(rotation=90, axis='x')
        ax.set_title(proteins[i],
                     fontdict={'fontsize': 25})

        offset = -0.5
        for specy in species.keys():
            add_label_band(ax,
                           offset, offset + len(species[specy]),
                           specy,
                           spine_pos=-0.075,
                           tip_pos=-0.05)
            offset = len(species[specy]) + offset
            ax.plot([offset, offset],
                    [-0.5, len(temp_results) - 0.5],
                    linewidth = 3.5 if i in [9, 14] else 2,
                    color ='k')
            ax.plot([-0.5, len(temp_results) - 0.5],
                    [offset, offset],
                    linewidth = 3.5 if i in [9, 14] else 2,
                    color='k')
            
        in_species_peptide_matches = temp_results.copy()
        out_species_peptide_matches = temp_results.copy()

        for specy, types in species.items():
            sub_search = ["HPV" + str(i) for i in types]
            other_cols = [i for i in temp_results.columns if i not in sub_search]
            for index, row in temp_results.iterrows():
                if index not in sub_search:
                    pass
                else:
                    out_species_peptide_matches.loc[index, sub_search] = np.inf
                    in_species_peptide_matches.loc[index, other_cols] = np.inf

        in_species_peptide_matches.to_csv("../results/in_species_peptide_matches_{}.csv".format(proteins[i]))
        out_species_peptide_matches.to_csv("../results/out_species_peptide_matches_{}.csv".format(proteins[i]))
        
        i = i + 1

    fig.suptitle('Heatmap of Matching Peptides Subseqences for 18 HLAs (6A, 6B, 6C) \n' +
                 '(threshold = {}, log-transformed)'.format(threshold),
                # + (', shared scale)' if shared_axis else ', scaled not shared)'),
                fontsize=40)
    plt.savefig('../figures/figure_2_' + colormap + 
                '_lognorm' if lognorm else '' + '.png', bbox_inches='tight')
#     plt.savefig('../figures/figure_2_' + colormap + 
#                 str('_lognorm' if lognorm else '') +
#                 '_threshold_' + str(threshold) +
#                 '.png', bbox_inches='tight')
# Out:
# /Users/antonalyakin/.virtualenvs/graphs/lib/python3.7/site-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning: default base will change from np.e to 10 in 3.4.  To suppress this warning specify the base keyword argument.

# %%
in_values_all = []
out_values_all = []

for protein in ["E1", "E2", "E6", "E7"]:
    print("protein: {}".format(protein))
    in_species_peptide_matches = pd.read_csv("../results/in_species_peptide_matches_{}.csv".format(protein),
                                        index_col=0)
    out_species_peptide_matches = pd.read_csv("../results/out_species_peptide_matches_{}.csv".format(protein),
                                         index_col=0)
    # display(in_species_peptide_matches.iloc[:6, :6])
    in_values = in_species_peptide_matches.values.copy()
    in_values[np.tril_indices(in_values.shape[0])] = np.inf
    in_group_values = in_values.flatten()[np.isfinite(in_values.flatten())]
    in_values_all.append(in_values)
    # display(out_species_peptide_matches.iloc[:6, :6])
    out_values = out_species_peptide_matches.values.copy()
    out_values[np.tril_indices(out_values.shape[0])] = np.inf
    out_group_values = out_values.flatten()[np.isfinite(out_values.flatten())]
    out_values_all.append(out_values)
    
    print("In-species statistics")
    print("Median: {}, Mean: {}, Min: {}, Max: {}, Var: {}".format(
            np.round(np.median(in_group_values), 4),
            np.round(in_group_values.mean(), 4),
            np.round(in_group_values.min(), 4),
            np.round(in_group_values.max(), 4),
            np.round(in_group_values.var()), 4))
    print("Out-species statistics")
    print("Median: {}, Mean: {}, Min: {}, Max: {}, Var: {}".format(
            np.round(np.median(out_group_values), 4),
            np.round(out_group_values.mean(), 4),
            np.round(out_group_values.min(), 4),
            np.round(out_group_values.max(), 4),
            np.round(out_group_values.var()), 4))
    print("Statistical Significance")
    print(stats.ttest_ind(in_group_values, out_group_values))
    print(stats.ranksums(in_group_values, out_group_values))
    print()
    print()
    
    fig2, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

    sns.histplot(out_group_values,
                 label="out species", 
                 bins=np.linspace(0, np.max(in_group_values), 20),
                 #color='blue',
                 ax=ax1)
    sns.histplot(in_group_values,
                 label="in species",
                 bins=np.linspace(0, np.max(in_group_values), 20),
                 color='orange',
                 ax=ax1)
    ax1.legend()
    ax1.set_title("homolgy in-species and out-species (not normalized)")
    sns.histplot(out_group_values,
                 label="out species", 
                 bins=np.linspace(0, np.max(in_group_values), 20),
                 #color='blue',
                 stat='density',
                 ax=ax2)
    sns.histplot(in_group_values,
                 label="in species",
                 bins=np.linspace(0, np.max(in_group_values), 20),
                 color='orange',
                 stat='density',
                 ax=ax2)
    ax2.legend()
    ax2.set_title("homolgy in-species and out-species (normalized to add to 1)");
    fig2.savefig('../figures/axillary_peptide_matches_in_out_species_{}.png'.format(protein),
                bbox_inches='tight')
# Out:
# protein: E1
# In-species statistics
# Median: 33.5, Mean: 36.4024, Min: 4.0, Max: 97.0, Var: 512.0
# Out-species statistics
# Median: 1.0, Mean: 2.4265, Min: 0.0, Max: 27.0, Var: 12.0
# Statistical Significance
# Ttest_indResult(statistic=60.010516395398064, pvalue=0.0)
# RanksumsResult(statistic=20.633577551877366, pvalue=1.3712067285066982e-94)
#
#
# protein: E2
# In-species statistics
# Median: 9.0, Mean: 11.3293, Min: 0.0, Max: 43.0, Var: 75.0
# Out-species statistics
# Median: 0.0, Mean: 0.3762, Min: 0.0, Max: 10.0, Var: 1.0
# Statistical Significance
# Ttest_indResult(statistic=53.53013155458245, pvalue=0.0)
# RanksumsResult(statistic=20.672985054232868, pvalue=6.064686369068077e-95)
#
#
# protein: E6
# In-species statistics
# Median: 3.0, Mean: 3.6402, Min: 0.0, Max: 19.0, Var: 15.0
# Out-species statistics
# Median: 0.0, Mean: 0.0234, Min: 0.0, Max: 3.0, Var: 0.0
# Statistical Significance
# Ttest_indResult(statistic=41.97125639621622, pvalue=1.36531644753173e-283)
# ...

# %%
in_values_all = np.array(in_values_all).sum(axis=0)
out_values_all = np.array(out_values_all).sum(axis=0)

# %%
in_group_values_all = in_values_all.flatten()[np.isfinite(in_values_all.flatten())]
out_group_values_all = out_values_all.flatten()[np.isfinite(out_values_all.flatten())]
    
print("Across All Proteins")
print("In-species statistics")
print("Median: {}, Mean: {}, Min: {}, Max: {}, Var: {}".format(
        np.round(np.median(in_group_values_all), 4),
        np.round(in_group_values_all.mean(), 4),
        np.round(in_group_values_all.min(), 4),
        np.round(in_group_values_all.max(), 4),
        np.round(in_group_values_all.var()), 4))
print("Out-species statistics")
print("Median: {}, Mean: {}, Min: {}, Max: {}, Var: {}".format(
        np.round(np.median(out_group_values_all), 4),
        np.round(out_group_values_all.mean(), 4),
        np.round(out_group_values_all.min(), 4),
        np.round(out_group_values_all.max(), 4),
        np.round(out_group_values_all.var()), 4))
print("Statistical Significance")
print(stats.ttest_ind(in_group_values_all, out_group_values_all))
print(stats.ranksums(in_group_values_all, out_group_values_all))
print()
print()


fig2, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(out_group_values_all,
             label="out species", 
             bins=np.linspace(0, np.max(in_group_values_all), 21),
             #color='blue',
             ax=ax1)
sns.histplot(in_group_values_all,
             label="in species",
             bins=np.linspace(0, np.max(in_group_values_all), 21),
             color='orange',
             ax=ax1)
ax1.legend()
ax1.set_title("homolgy in-species and out-species (not normalized)")
sns.histplot(out_group_values_all,
             label="out species", 
             bins=np.linspace(0, np.max(in_group_values_all), 21),
             #color='blue',
             stat='density',
             ax=ax2)
sns.histplot(in_group_values_all,
             label="in species",
             bins=np.linspace(0, np.max(in_group_values_all), 21),
             color='orange',
             stat='density',
             ax=ax2)
ax2.legend()
ax2.set_title("homolgy in-species and out-species (normalized to add to 1)");
fig2.savefig('../figures/axillary_peptide_matches_in_out_species_all.png'.format(protein),
            bbox_inches='tight')
# Out:
# Across All Proteins
# In-species statistics
# Median: 47.5, Mean: 53.0427, Min: 10.0, Max: 153.0, Var: 1168.0
# Out-species statistics
# Median: 1.0, Mean: 2.8495, Min: 0.0, Max: 27.0, Var: 16.0
# Statistical Significance
# Ttest_indResult(statistic=61.31721573545174, pvalue=0.0)
# RanksumsResult(statistic=21.09985728942568, pvalue=7.977651531814643e-99)

# %%
pd.DataFrame(in_values_all[:10,:10],
             columns=in_species_peptide_matches.columns[:10],
            ).set_index(in_species_peptide_matches.columns[:10])
# Out:
#        HPV32  HPV42  HPV3  HPV10  HPV28  HPV29  HPV61  HPV2  HPV27  HPV57
# HPV32    inf   87.0   inf    inf    inf    inf    inf   inf    inf    inf
# HPV42    inf    inf   inf    inf    inf    inf    inf   inf    inf    inf
# HPV3     inf    inf   inf   73.0   94.0   64.0    inf   inf    inf    inf
# HPV10    inf    inf   inf    inf   93.0   77.0    inf   inf    inf    inf
# HPV28    inf    inf   inf    inf    inf   76.0    inf   inf    inf    inf
# HPV29    inf    inf   inf    inf    inf    inf    inf   inf    inf    inf
# HPV61    inf    inf   inf    inf    inf    inf    inf   inf    inf    inf
# HPV2     inf    inf   inf    inf    inf    inf    inf   inf  152.0  124.0
# HPV27    inf    inf   inf    inf    inf    inf    inf   inf    inf  127.0
# HPV57    inf    inf   inf    inf    inf    inf    inf   inf    inf    inf

# %%
pd.DataFrame(out_values_all[:10,:10],
             columns=in_species_peptide_matches.columns[:10],
            ).set_index(in_species_peptide_matches.columns[:10])
# Out:
#        HPV32  HPV42  HPV3  HPV10  HPV28  HPV29  HPV61  HPV2  HPV27  HPV57
# HPV32    inf    inf   2.0    3.0    3.0    4.0    1.0   2.0    5.0    7.0
# HPV42    inf    inf   1.0    2.0    2.0    4.0    1.0   3.0    4.0    5.0
# HPV3     inf    inf   inf    inf    inf    inf   13.0  22.0   22.0   20.0
# HPV10    inf    inf   inf    inf    inf    inf   19.0  20.0   24.0   22.0
# HPV28    inf    inf   inf    inf    inf    inf    8.0  21.0   24.0   27.0
# HPV29    inf    inf   inf    inf    inf    inf    7.0  25.0   25.0   19.0
# HPV61    inf    inf   inf    inf    inf    inf    inf  19.0   20.0   14.0
# HPV2     inf    inf   inf    inf    inf    inf    inf   inf    inf    inf
# HPV27    inf    inf   inf    inf    inf    inf    inf   inf    inf    inf
# HPV57    inf    inf   inf    inf    inf    inf    inf   inf    inf    inf
